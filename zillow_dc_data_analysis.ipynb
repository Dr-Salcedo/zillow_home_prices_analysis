# %%
import pandas as pd
from pandas import Series
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import datetime as datetime
# %matplotlib inline

# %%
df_dc_analysis=pd.read_csv("zillow_dc_cleaned.csv")
df_dc_analysis.head()
# Out:
#    Unnamed: 0  20002   20009   20011  20019  20001   20020   20008   20003  \
# 0  1996-04-01  94300  178800  118900  91300  92000  104500  450100  130000
# 1  1996-05-01  94000  179200  118500  91000  92600  103800  448200  130100
# 2  1996-06-01  93700  179600  118200  90600  93200  103000  446300  130200
# 3  1996-07-01  93600  180000  117800  90400  93900  102200  444500  130400
# 4  1996-08-01  93400  180300  117600  90100  94600  101400  442900  130600
#
#    20032   20016   20010   20007   20024   20017   20018   20037   20015  \
# 0  85700  362000  110500  358100  209800  121700  123000  277800  312400
# 1  85500  361200  111200  356000  208200  121400  122400  275800  311000
# 2  85400  360300  112000  353900  206600  121200  121800  273700  309800
# 3  85200  359400  112900  351700  205000  121000  121200  271600  308700
# 4  85000  358500  113800  349600  203300  120900  120700  269500  307900
#
#     20012
# 0  185000
# 1  184900
# 2  184700
# 3  184400
# 4  184100

# %%
df_dc_analysis.index=pd.to_datetime(df_dc_analysis.index)

df_dc_analysis.index
# Out:
# DatetimeIndex([          '1970-01-01 00:00:00',
#                '1970-01-01 00:00:00.000000001',
#                '1970-01-01 00:00:00.000000002',
#                '1970-01-01 00:00:00.000000003',
#                '1970-01-01 00:00:00.000000004',
#                '1970-01-01 00:00:00.000000005',
#                '1970-01-01 00:00:00.000000006',
#                '1970-01-01 00:00:00.000000007',
#                '1970-01-01 00:00:00.000000008',
#                '1970-01-01 00:00:00.000000009',
#                ...
#                '1970-01-01 00:00:00.000000255',
#                '1970-01-01 00:00:00.000000256',
#                '1970-01-01 00:00:00.000000257',
#                '1970-01-01 00:00:00.000000258',
#                '1970-01-01 00:00:00.000000259',
#                '1970-01-01 00:00:00.000000260',
#                '1970-01-01 00:00:00.000000261',
#                '1970-01-01 00:00:00.000000262',
#                '1970-01-01 00:00:00.000000263',
# ...

# %%
df_dc_analysis.head()
# Out:
#                                     Date  20002   20009   20011  20019  20001  \
# 1970-01-01 00:00:00.000000000 1996-04-01  94300  178800  118900  91300  92000
# 1970-01-01 00:00:00.000000001 1996-05-01  94000  179200  118500  91000  92600
# 1970-01-01 00:00:00.000000002 1996-06-01  93700  179600  118200  90600  93200
# 1970-01-01 00:00:00.000000003 1996-07-01  93600  180000  117800  90400  93900
# 1970-01-01 00:00:00.000000004 1996-08-01  93400  180300  117600  90100  94600
#
#                                 20020   20008   20003  20032   20016   20010  \
# 1970-01-01 00:00:00.000000000  104500  450100  130000  85700  362000  110500
# 1970-01-01 00:00:00.000000001  103800  448200  130100  85500  361200  111200
# 1970-01-01 00:00:00.000000002  103000  446300  130200  85400  360300  112000
# 1970-01-01 00:00:00.000000003  102200  444500  130400  85200  359400  112900
# 1970-01-01 00:00:00.000000004  101400  442900  130600  85000  358500  113800
#
# ...

# %%
df_dc_analysis.index.astype(int)
# Out:
# pandas.core.indexes.numeric.Int64Index

# %%
df_dc_analysis.head()
# Out:
#                                     Date  20002   20009   20011  20019  20001  \
# 1970-01-01 00:00:00.000000000 1996-04-01  94300  178800  118900  91300  92000
# 1970-01-01 00:00:00.000000001 1996-05-01  94000  179200  118500  91000  92600
# 1970-01-01 00:00:00.000000002 1996-06-01  93700  179600  118200  90600  93200
# 1970-01-01 00:00:00.000000003 1996-07-01  93600  180000  117800  90400  93900
# 1970-01-01 00:00:00.000000004 1996-08-01  93400  180300  117600  90100  94600
#
#                                 20020   20008   20003  20032   20016   20010  \
# 1970-01-01 00:00:00.000000000  104500  450100  130000  85700  362000  110500
# 1970-01-01 00:00:00.000000001  103800  448200  130100  85500  361200  111200
# 1970-01-01 00:00:00.000000002  103000  446300  130200  85400  360300  112000
# 1970-01-01 00:00:00.000000003  102200  444500  130400  85200  359400  112900
# 1970-01-01 00:00:00.000000004  101400  442900  130600  85000  358500  113800
#
# ...

# %%
df_dc_analysis.plot(figsize=(12,7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-a4a702af235c> in <module>
# ----> 1 df_dc_analysis.plot()
#
# /anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# ...

# %%
df_dc_analysis.boxplot(figsize=(12,7))

# %%
df_dc_analysis.head()
# Out:
#         Date  20002   20009   20011  20019  20001   20020   20008   20003  \
# 0 1996-04-01  94300  178800  118900  91300  92000  104500  450100  130000
# 1 1996-05-01  94000  179200  118500  91000  92600  103800  448200  130100
# 2 1996-06-01  93700  179600  118200  90600  93200  103000  446300  130200
# 3 1996-07-01  93600  180000  117800  90400  93900  102200  444500  130400
# 4 1996-08-01  93400  180300  117600  90100  94600  101400  442900  130600
#
#    20032   20016   20010   20007   20024   20017   20018   20037   20015  \
# 0  85700  362000  110500  358100  209800  121700  123000  277800  312400
# 1  85500  361200  111200  356000  208200  121400  122400  275800  311000
# 2  85400  360300  112000  353900  206600  121200  121800  273700  309800
# 3  85200  359400  112900  351700  205000  121000  121200  271600  308700
# 4  85000  358500  113800  349600  203300  120900  120700  269500  307900
#
#     20012
# 0  185000
# 1  184900
# 2  184700
# 3  184400
# 4  184100

# %%
df_dc_analysis.index
# Out:
# DatetimeIndex([          '1970-01-01 00:00:00',
#                '1970-01-01 00:00:00.000000001',
#                '1970-01-01 00:00:00.000000002',
#                '1970-01-01 00:00:00.000000003',
#                '1970-01-01 00:00:00.000000004',
#                '1970-01-01 00:00:00.000000005',
#                '1970-01-01 00:00:00.000000006',
#                '1970-01-01 00:00:00.000000007',
#                '1970-01-01 00:00:00.000000008',
#                '1970-01-01 00:00:00.000000009',
#                ...
#                '1970-01-01 00:00:00.000000255',
#                '1970-01-01 00:00:00.000000256',
#                '1970-01-01 00:00:00.000000257',
#                '1970-01-01 00:00:00.000000258',
#                '1970-01-01 00:00:00.000000259',
#                '1970-01-01 00:00:00.000000260',
#                '1970-01-01 00:00:00.000000261',
#                '1970-01-01 00:00:00.000000262',
#                '1970-01-01 00:00:00.000000263',
# ...
